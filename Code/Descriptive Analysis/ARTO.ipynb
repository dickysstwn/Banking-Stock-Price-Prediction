# %% [markdown]
# # **Stock (ARTO) - Pre-Processing & Descriptive Analysis**

# %% [markdown]
# ## **Data Load & Understanding**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %%
df = pd.read_csv('data/ARTO.csv')

# %%
# Display the contents of the dataset as a whole
df
# Out:
#             Date    Open    High     Low   Close  Adj Close      Volume
# 0     2018-12-31   184.0   184.0   184.0   184.0      184.0         0.0
# 1     2019-01-01   184.0   184.0   184.0   184.0      184.0         0.0
# 2     2019-01-02   189.0   199.0   176.0   188.0      188.0    664200.0
# 3     2019-01-03   188.0   188.0   178.0   182.0      182.0    296500.0
# 4     2019-01-04   182.0   187.0   180.0   183.0      183.0    409100.0
# ...          ...     ...     ...     ...     ...        ...         ...
# 1228  2023-12-21  2950.0  3000.0  2900.0  2970.0     2970.0  11397400.0
# 1229  2023-12-22  2970.0  3080.0  2920.0  2930.0     2930.0  14809300.0
# 1230  2023-12-27  2960.0  3010.0  2940.0  2970.0     2970.0   7535000.0
# 1231  2023-12-28  2990.0  3010.0  2920.0  2940.0     2940.0   7909800.0
# 1232  2023-12-29  2960.0  2970.0  2860.0  2900.0     2900.0   7581900.0
#
# [1233 rows x 7 columns]

# %%
# Checking the data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1233 entries, 0 to 1232
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1233 non-null   object
#  1   Open       1232 non-null   float64
#  2   High       1232 non-null   float64
#  3   Low        1232 non-null   float64
#  4   Close      1232 non-null   float64
#  5   Adj Close  1232 non-null   float64
#  6   Volume     1232 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 67.6+ KB

# %%
# Check the number of columns and rows in the data
df.shape
# Out:
# (1233, 7)

# %%
# Shows a description of the data
df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count   1232.000000   1232.000000   1232.000000   1232.000000   1232.000000
# mean    5600.612121   5753.859220   5450.548157   5596.269448   5596.269448
# std     5389.609631   5515.388388   5246.803650   5383.459744   5383.459744
# min      132.000000    147.000000    130.000000    145.000000    145.000000
# 25%     2107.500000   2167.500000   2007.500000   2113.590516   2113.590516
# 50%     3035.000000   3140.000000   2935.000000   3025.000000   3025.000000
# 75%     9550.000000   9762.500000   9281.250000   9512.500000   9512.500000
# max    19100.000000  19500.000000  18700.000000  19000.000000  19000.000000
#
#              Volume
# count  1.232000e+03
# mean   1.444095e+07
# std    2.312220e+07
# min    0.000000e+00
# 25%    8.981975e+04
# 50%    8.153014e+06
# 75%    2.091345e+07
# max    3.802639e+08

# %%
df.head(10)
# Out:
#          Date   Open   High    Low  Close  Adj Close    Volume
# 0  2018-12-31  184.0  184.0  184.0  184.0      184.0       0.0
# 1  2019-01-01  184.0  184.0  184.0  184.0      184.0       0.0
# 2  2019-01-02  189.0  199.0  176.0  188.0      188.0  664200.0
# 3  2019-01-03  188.0  188.0  178.0  182.0      182.0  296500.0
# 4  2019-01-04  182.0  187.0  180.0  183.0      183.0  409100.0
# 5  2019-01-07  188.0  195.0  170.0  178.0      178.0  351700.0
# 6  2019-01-08  182.0  189.0  175.0  180.0      180.0  587000.0
# 7  2019-01-09  186.0  186.0  175.0  175.0      175.0  124500.0
# 8  2019-01-10  183.0  183.0  175.0  179.0      179.0  158700.0
# 9  2019-01-11  180.0  182.0  177.0  180.0      180.0  306900.0

# %%
df.tail(10)
# Out:
#             Date    Open    High     Low   Close  Adj Close      Volume
# 1223  2023-12-14  3500.0  3500.0  3250.0  3300.0     3300.0  89153500.0
# 1224  2023-12-15  3310.0  3360.0  3150.0  3210.0     3210.0  32270700.0
# 1225  2023-12-18  3210.0  3210.0  2850.0  2950.0     2950.0  56602100.0
# 1226  2023-12-19  2910.0  3080.0  2910.0  3010.0     3010.0  28597100.0
# 1227  2023-12-20  3040.0  3070.0  2960.0  2970.0     2970.0  16038200.0
# 1228  2023-12-21  2950.0  3000.0  2900.0  2970.0     2970.0  11397400.0
# 1229  2023-12-22  2970.0  3080.0  2920.0  2930.0     2930.0  14809300.0
# 1230  2023-12-27  2960.0  3010.0  2940.0  2970.0     2970.0   7535000.0
# 1231  2023-12-28  2990.0  3010.0  2920.0  2940.0     2940.0   7909800.0
# 1232  2023-12-29  2960.0  2970.0  2860.0  2900.0     2900.0   7581900.0

# %%
# Melihat nilai max pada setiap kolom yang ada
max_kolom = df.max()
print("Nilai Max dari setiap kolom:")
print(max_kolom)

# Melihat nilai min pada setiap kolom yang ada
min_kolom = df.min()
print("\nNilai Min dari setiap kolom:")
print(min_kolom)

# Melihat nilai mean pada setiap kolom yang ada
mean_kolom = round(df.mean())
print("\nNilai Mean dari setiap kolom:")
print(mean_kolom)
# Out:
# Nilai Max dari setiap kolom:
# Date          2023-12-29
# Open               19100
# High               19500
# Low                18700
# Close              19000
# Adj Close          19000
# Volume       3.80264e+08
# dtype: object
#
# Nilai Min dari setiap kolom:
# Date         2018-12-31
# Open                132
# High                147
# Low                 130
# Close               145
# Adj Close           145
# Volume                0
# dtype: object
#
# Nilai Mean dari setiap kolom:
# Open             5601.0
# High             5754.0
# Low              5451.0
# Close            5596.0
# Adj Close        5596.0
# Volume       14440953.0
# dtype: float64

# %% [markdown]
# ## **Data Cleaning**

# %% [markdown]
# ### **Detecting Outlier**

# %%
df_num = df.select_dtypes(include = ['float'])

# %%
# Detecting outliers using boxplot
for i in df_num:
    sns.boxplot(data= df_num, x=i)
    plt.show()

# %%
# Function to identify outliers using the IQR method
def find_outliers_iqr(column):
    if df[column].dtype in ['float']:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
        return outliers
    else:
        return pd.DataFrame()

# Identify columns with outliers
columns_with_outliers = []
outliers_counts = {}

for column in df.columns:
    outliers = find_outliers_iqr(column)
    if not outliers.empty:
        columns_with_outliers.append(column)
        outliers_counts[column] = len(outliers)

# %%
# Display columns with outliers and number of outliers
print("Columns with outliers and the number of outliers detected:")
for column in columns_with_outliers:
    print(f"{column}: {outliers_counts[column]} outliers")
# Out:
# Columns with outliers and the number of outliers detected:
# Volume: 53 outliers

# %%
# Strategy for handling outliers: Delete rows containing outliers
for column in columns_with_outliers:
    outliers = find_outliers_iqr(column)
    df = df.drop(outliers.index)

# %%
# Display columns with outliers and number of outliers
print("Columns with outliers and the number of outliers detected:")
for column in columns_with_outliers:
    print(f"{column}: {outliers_counts[column]} outliers")
# Out:
# Columns with outliers and the number of outliers detected:

# %%
df.isna().sum()
# Out:
# Date         0
# Open         1
# High         1
# Low          1
# Close        1
# Adj Close    1
# Volume       1
# dtype: int64

# %% [markdown]
# ### **Data Type Transformation**

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1161 entries, 0 to 1232
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1161 non-null   datetime64[ns]
#  1   Open       1160 non-null   float64
#  2   High       1160 non-null   float64
#  3   Low        1160 non-null   float64
#  4   Close      1160 non-null   float64
#  5   Adj Close  1160 non-null   float64
#  6   Volume     1160 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 72.6 KB

# %% [markdown]
# ### **Handling Missing Value**

# %% [markdown]
# Karna missing value hanya ada 1 di setiap kolom menggunakan nilai mean untuk mengisi missing value

# %%
df.fillna(df.mean(), inplace=True)
# Out:
# <ipython-input-51-bf934754a5b1>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df.fillna(df.mean(), inplace=True)

# %%
df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# ## **Data Visualization**

# %%
#Close
plt.figure(figsize=(8, 6))
plt.plot(df['Date'], df['Close'], linestyle='-', color='b')

# Label sumbu x dan y
plt.xlabel('Date')
plt.ylabel('Close')

# Judul grafik
plt.title('Close Price over Time')

# Menampilkan grafik
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Saving Cleaned Data to csv**

# %%
df.to_csv('ARTO_Cleaned.csv', index=False)
